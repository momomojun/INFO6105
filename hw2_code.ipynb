# %%
# Create a binary decision tree using Gini index impurity measure 
# over the diabetes dataset to predict Outcome (as the label) by other attributes (as features).

# Consider the following ranges of values for hyper-parameters:
# max_depth = [3, 5]
# min_sample_split= [5, 10]
# min_samples_leaf= [3, 5]
# min_impurity_decrease = [0.01, 0.001]
# ccp_alpha = [0.001, 0.0001]

# Spilt data into train, test, and validation (72%, 20%, 8%) 
# and use validation data to select best hyper-parameter.
# Calculate accuracy of the best Dtree on test data.
# Extract three rules from the decision tree.
